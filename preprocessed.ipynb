# %%
# Kaggle Dataset Link: https://www.kaggle.com/datasets/cyberprince/linux-terminal-commands-dataset
# import json

# input_file = "./archive/LINUX_TERMINAL_COMMANDS.jsonl"
# output_file = "finetune_dataset.json"

# processed_data = []

# def generate_instruction(description):
#     return f"How do I {description.rstrip('.')}?"

# with open(input_file, "r", encoding="utf-8") as infile:
#     for line in infile:
#         try:
#             entry = json.loads(line.strip())

#             instruction = generate_instruction(entry.get("description", ""))  
#             output = entry.get("command", "").strip()

#             if instruction and output:
#                 processed_data.append({"instruction": instruction,"output": output})

#         except json.JSONDecodeError as e:
#             print("Skipping line due to JSON error:", e)

# with open(output_file, "w", encoding="utf-8") as outfile:
#     json.dump(processed_data, outfile, indent=2, ensure_ascii=False)

# print(f"Processed {len(processed_data)} entries.")
# print(f"Saved to {output_file}")

# %%
import torch
import transformers
import nltk
from rouge_score import rouge_scorer

print("All libraries loaded successfully")
print(f"PyTorch version: {torch.__version__}")
print(f"Using device: {'CUDA' if torch.cuda.is_available() else 'CPU'}")
# Out:
# All libraries loaded successfully
# PyTorch version: 2.7.0+cpu
# Using device: CPU
